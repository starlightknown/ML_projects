# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
pil = Image.open("thor.png")

# %%
pil
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=480x709 at 0x7FAF401E1C70>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (709, 480, 3)

# %%
work = arr.copy()

# %%
work[:,:,[0,1]]=-100 #you have cut red and green,only blue is left
#you can change the number after '=' to get new filters, 0 for original color

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray,cmap="gray") #cmap is color map
